# %%
from pyspark.sql.functions import*

# %%
looktables_rules = {
    "rule1" : "showid is NOT NULL"
}

# %%
@dlt.table(
    name = "gold_netflixdirections"
)
@dlt.expect_all_or_drop(looktables_rules)
def myfunc():
    df = spark.readStream("abfss://rg_netflix_project@onelake.dfs.fabric.microsoft.com/bronze.Lakehouse/Tables/dbo/netflix_directors")
    return df

# %%
@dlt.table(
    name = "gold_netflixcast"
)

def myfunc():
    df = spark.readStream("abfss://rg_netflix_project@onelake.dfs.fabric.microsoft.com/bronze.Lakehouse/Tables/dbo/netflix_cast")
    return df

# %%
@dlt.table(
    name = "gold_netflixcountries"
)

def myfunc():
    df = spark.readStream("abfss://rg_netflix_project@onelake.dfs.fabric.microsoft.com/bronze.Lakehouse/Tables/dbo/netflix_countries")
    return df

# %%
@dlt.table(
    name = "gold_netflixcategory"
)

def myfunc():
    df = spark.readStream("abfss://rg_netflix_project@onelake.dfs.fabric.microsoft.com/bronze.Lakehouse/Tables/dbo/netflix_")
    return df

# %%
@dlt.table

def gold_stg_netflixtitles:

    df = spark.readStream.format("delta").load("abfss://rg_netflix_project@onelake.dfs.fabric.microsoft.com/bronze.Lakehouse/Tables/dbo/netflix_titles")
    return df

# %%
@dlt.view

def gold_trns_netflixtitles:
    df = spark.readStream.table("LIVE.gold_stg_netflixtitles")
    df = df.withColumn("newflag",lit(1))
    return df

# %%
masterdata_rules = {
    "rule1" : "newflag is NOT NULL",
    "rule2" : "showid is NOT NULL"
}

# %%
@dlt.table

@dlt.expect_all_or_drop(masterdata_rules)
def gold_netflixtitles:

    df = spark.readStream.table("LIVE.gold_trns_netflixtitles")

    return df
